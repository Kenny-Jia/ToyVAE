# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
from sklearn.model_selection import train_test_split
import tensorflow as tf
import tensorflow.math as tfmath
import tensorflow.keras as keras
from tensorflow.keras import layers, Model
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import load_model
from sklearn.metrics import roc_curve, auc
import sklearn.metrics as sk
# Out:
# 2024-10-06 20:20:34.201000: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-06 20:20:34.278542: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import PReLU, Input, LSTM, Flatten, Concatenate, Dense, Conv2D, TimeDistributed, MaxPooling2D, LeakyReLU, ReLU, Dropout, BatchNormalization, Activation
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.metrics import Precision
from qkeras import QActivation, QDense, QConv2D, QBatchNormalization, QConv2DBatchnorm
from qkeras import quantized_relu, quantized_bits
from tensorflow.keras.regularizers import l1, l2, l1_l2

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
tf.debugging.set_log_device_placement(False)
# Out:
# Num GPUs Available:  1
# 2024-10-06 20:20:43.242308: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 20:20:43.260751: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 20:20:43.261000: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
#preprocessed_SNL_data.h5 is located under s3df /sdf/home/h/hjia625/
with h5py.File('/eos/user/h/hjia/AnomalyDetection/liam_AD/training_notebooks/preprocessed_SNL_data.h5', 'r') as hf:
    X_train = hf['X_train'][:]
    X_test  = hf['X_test'][:]
    Ato4l_data  = hf['Ato4l_data'][:]
    hToTauTau_data  = hf['hToTauTau_data'][:]
    hChToTauNu_data  = hf['hChToTauNu_data'][:]
    leptoquark_data = hf['leptoquark_data'][:]
    print("Data loaded from preprocessed_SNL_data.h5")
# Out:
# Data loaded from preprocessed_SNL_data.h5

# %%
# filename = "/eos/user/h/hjia/AnomalyDetection/liam_AD/training_notebooks/SM_ZeroBias_dataset.h5"
# with h5py.File(filename, 'r') as file:
#     X_train = np.array(file['X_train'])
#     X_test = np.array(file['X_test'])
#     X_val = np.array(file['X_val'])
# X_train = np.vstack((X_train, X_val))
# print(X_train.shape)

# %%
# def scale_columns(arr):
#     # Check if the input array has 57 columns
#     if arr.shape[1] != 57:
#         raise ValueError("Input array must have 57 columns")
    
#     # Create a copy of the input array to avoid modifying the original
#     scaled_arr = arr.copy()
# #     met_scale = 1
# #     em_scale = 1
# #     tau_scale = 1
# #     jet_scale = 1
# #     muon_scale = 1
#     met_scale = 512
#     em_scale = 128
#     tau_scale = 128
#     jet_scale = 256
#     muon_scale = 32
#     # Define the scaling factors for each column
#     scale_dict = {
#         0: 1/met_scale,
#         3: 1/em_scale, 6: 1/em_scale, 9: 1/em_scale, 12: 1/em_scale, 15: 1/tau_scale,
#         18: 1/tau_scale, 21: 1/tau_scale, 24: 1/tau_scale,
#         27: 1/jet_scale, 30: 1/jet_scale, 33: 1/jet_scale, 36: 1/jet_scale, 39: 1/jet_scale, 42: 1/jet_scale,
#         45: 1/muon_scale, 48: 1/muon_scale, 51: 1/muon_scale, 54: 1/muon_scale
#     }

#     # Apply scaling to the specified columns
#     for col, scale_factor in scale_dict.items():
#         scaled_arr[:, col] *= scale_factor
    
#     return scaled_arr
# X_train = scale_columns(X_train)
# X_test = scale_columns(X_test)

# %%
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# scaler.fit(X_train)
# X_train = scaler.transform(X_train)
# X_test = scaler.transform(X_test)

# %%
def analyze_columns(arr):
    # Check if the input array has 57 columns
    if arr.shape[1] != 57:
        raise ValueError("Input array must have 57 columns")

    for col in range(57):
        column = arr[:, col]
        
        # Calculate statistics
        mean_val = np.mean(column)
        min_val = np.min(column)
        max_val = np.max(column)
        has_nan = np.isnan(column).any()
        
        # Print results
        print(f"Column {col + 1}:")
        print(f"  Mean: {mean_val:.4f}")
        print(f"  Min: {min_val:.4f}")
        print(f"  Max: {max_val:.4f}")
        print(f"  Contains NaN: {has_nan}")
        print()  # Empty line for readability
analyze_columns(X_train)
# Out:
# Column 1:
#   Mean: -0.0000
#   Min: -1.9571
#   Max: 53.1526
#   Contains NaN: False
#
# Column 2:
#   Mean: 0.0000
#   Min: 0.0000
#   Max: 0.0000
#   Contains NaN: False
#
# Column 3:
#   Mean: 0.0000
#   Min: -1.7323
#   Max: 1.7311
#   Contains NaN: False
#
# Column 4:
#   Mean: -0.0000
#   Min: -0.9537
#   Max: 47.1318
#   Contains NaN: False
#
# Column 5:
#   Mean: -0.0000
#   Min: -2.4819
#   Max: 2.4821
#   Contains NaN: False
#
# Column 6:
#   Mean: -0.0000
#   Min: -2.3496
#   Max: 2.3489
#   Contains NaN: False
#
# Column 7:
#   Mean: -0.0000
#   Min: -0.0355
#   Max: 200.8080
#   Contains NaN: False
#
# Column 8:
#   Mean: -0.0000
#   Min: -43.0203
#   Max: 43.0213
#   Contains NaN: False
#
# Column 9:
#   Mean: 0.0000
#   Min: -34.6662
#   Max: 34.6653
#   Contains NaN: False
#
# Column 10:
#   Mean: 0.0000
#   Min: -0.0108
#   Max: 302.0646
#   Contains NaN: False
#
# Column 11:
#   Mean: -0.0000
#   Min: -181.6179
#   Max: 181.7817
#   Contains NaN: False
#
# Column 12:
#   Mean: -0.0000
#   Min: -130.9459
#   Max: 130.8367
#   Contains NaN: False
#
# Column 13:
#   Mean: -0.0000
#   Min: -0.0028
#   Max: 660.7622
#   Contains NaN: False
#
# Column 14:
#   Mean: 0.0000
#   Min: -520.3063
#   Max: 686.6438
#   Contains NaN: False
#
# Column 15:
#   Mean: -0.0000
#   Min: -487.7219
#   Max: 484.9506
#   Contains NaN: False
#
# Column 16:
#   Mean: 0.0000
#   Min: -0.8222
#   Max: 33.0882
#   Contains NaN: False
#
# Column 17:
#   Mean: 0.0000
#   Min: -2.5472
#   Max: 2.5471
#   Contains NaN: False
#
# Column 18:
#   Mean: 0.0000
#   Min: -2.5510
#   Max: 2.5516
#   Contains NaN: False
#
# Column 19:
#   Mean: 0.0000
#   Min: -0.0297
#   Max: 291.0383
#   Contains NaN: False
#
# Column 20:
#   Mean: 0.0000
#   Min: -47.0408
#   Max: 47.0603
#   Contains NaN: False
#
# Column 21:
#   Mean: 0.0000
#   Min: -41.7168
#   Max: 41.7156
#   Contains NaN: False
#
# Column 22:
#   Mean: -0.0000
#   Min: -0.0083
#   Max: 421.5737
#   Contains NaN: False
#
# Column 23:
#   Mean: -0.0000
#   Min: -205.2899
#   Max: 202.9845
#   Contains NaN: False
#
# Column 24:
#   Mean: -0.0000
#   Min: -174.2299
#   Max: 173.6709
#   Contains NaN: False
#
# Column 25:
#   Mean: -0.0000
#   Min: -0.0020
#   Max: 940.8060
#   Contains NaN: False
#
# Column 26:
#   Mean: 0.0000
#   Min: -810.1814
#   Max: 794.4273
#   Contains NaN: False
#
# Column 27:
#   Mean: -0.0000
#   Min: -722.3286
#   Max: 612.0592
#   Contains NaN: False
#
# Column 28:
#   Mean: -0.0000
#   Min: -0.5123
#   Max: 58.0216
#   Contains NaN: False
#
# Column 29:
#   Mean: 0.0000
#   Min: -3.8580
#   Max: 3.8601
#   Contains NaN: False
#
# Column 30:
#   Mean: 0.0000
#   Min: -2.7959
#   Max: 2.7976
#   Contains NaN: False
#
# Column 31:
#   Mean: -0.0000
#   Min: -0.2677
#   Max: 109.7365
#   Contains NaN: False
#
# Column 32:
#   Mean: 0.0000
#   Min: -6.3577
#   Max: 6.3593
#   Contains NaN: False
#
# Column 33:
#   Mean: 0.0000
#   Min: -5.0049
#   Max: 5.0044
#   Contains NaN: False
#
# Column 34:
#   Mean: 0.0000
#   Min: -0.1481
#   Max: 123.6013
#   Contains NaN: False
#
# Column 35:
#   Mean: -0.0000
#   Min: -11.6921
#   Max: 11.6929
#   Contains NaN: False
#
# Column 36:
#   Mean: -0.0000
#   Min: -9.2581
#   Max: 9.2558
#   Contains NaN: False
#
# Column 37:
#   Mean: 0.0000
#   Min: -0.0871
#   Max: 101.4869
#   Contains NaN: False
#
# Column 38:
#   Mean: -0.0000
#   Min: -21.1709
#   Max: 21.1645
#   Contains NaN: False
#
# Column 39:
#   Mean: -0.0000
#   Min: -16.2261
#   Max: 16.2256
#   Contains NaN: False
#
# Column 40:
#   Mean: -0.0000
#   Min: -0.0575
#   Max: 120.7499
#   Contains NaN: False
#
# Column 41:
#   Mean: -0.0000
#   Min: -34.5995
#   Max: 34.6021
#   Contains NaN: False
#
# Column 42:
#   Mean: -0.0000
#   Min: -25.6311
#   Max: 25.6354
#   Contains NaN: False
#
# Column 43:
#   Mean: -0.0000
#   Min: -0.0399
#   Max: 108.0682
#   Contains NaN: False
#
# Column 44:
#   Mean: -0.0000
#   Min: -52.7219
#   Max: 52.7200
#   Contains NaN: False
#
# Column 45:
#   Mean: 0.0000
#   Min: -38.4837
#   Max: 38.4987
#   Contains NaN: False
#
# Column 46:
#   Mean: -0.0000
#   Min: -0.0274
#   Max: 142.9166
#   Contains NaN: False
#
# Column 47:
#   Mean: 0.0000
#   Min: -80.5176
#   Max: 79.8578
#   Contains NaN: False
#
# Column 48:
#   Mean: 0.0000
#   Min: -57.4688
#   Max: 57.4615
#   Contains NaN: False
#
# Column 49:
#   Mean: 0.0000
#   Min: -0.0182
#   Max: 223.2545
#   Contains NaN: False
#
# Column 50:
#   Mean: 0.0000
#   Min: -117.8208
#   Max: 117.5744
#   Contains NaN: False
#
# Column 51:
#   Mean: -0.0000
#   Min: -87.9387
#   Max: 88.1077
#   Contains NaN: False
#
# Column 52:
#   Mean: -0.0000
#   Min: -0.0117
#   Max: 339.2351
#   Contains NaN: False
#
# Column 53:
#   Mean: -0.0000
#   Min: -187.4638
#   Max: 191.8051
#   Contains NaN: False
#
# Column 54:
#   Mean: 0.0000
#   Min: -139.8838
#   Max: 139.1267
#   Contains NaN: False
#
# Column 55:
#   Mean: -0.0000
#   Min: -0.0071
#   Max: 297.2272
#   Contains NaN: False
#
# Column 56:
#   Mean: 0.0000
#   Min: -324.9908
#   Max: 280.1775
#   Contains NaN: False
#
# Column 57:
#   Mean: -0.0000
#   Min: -220.9851
#   Max: 220.6210
#   Contains NaN: False

# %%
class Sampling(keras.layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

def Qmake_encoder_set_weights(input_dim,h_dim_1,h_dim_2,latent_dim):
    l2_factor = 1e-2
    inputs = keras.Input(shape=(input_dim), name = "inputs")
#     x = BatchNormalization(name="BN0")(inputs)
    x = Dense(h_dim_1,
             kernel_initializer=keras.initializers.HeNormal(seed=None),
             bias_initializer=keras.initializers.Zeros(),
             kernel_regularizer=l1_l2(l1=0, l2=l2_factor),
             name = "dense1")(inputs)
#     x = BatchNormalization(name="BN1")(x)
#     x = ReLU(name="relu1")(x)
    x = ReLU(name="relu1")(x)
    x = Dense(h_dim_2,
             kernel_initializer=keras.initializers.HeNormal(seed=None),
             bias_initializer=keras.initializers.Zeros(),
             kernel_regularizer=l1_l2(l1=0, l2=l2_factor),
             name = "dense2")(x)    
#     x = BatchNormalization(name="BN2")(x)
    x = ReLU(name="relu2")(x)
    z_mean=Dense(latent_dim, name='z_mean',
                  kernel_initializer=keras.initializers.HeNormal(seed=None),
                  bias_initializer=keras.initializers.Zeros(),
                  kernel_regularizer=l1_l2(l1=0, l2=l2_factor))(x)
    z_logvar=Dense(latent_dim, name='z_log_var',
                          kernel_initializer=keras.initializers.Zeros(),
                          bias_initializer=keras.initializers.Zeros(),
                          kernel_regularizer=l1_l2(l1=0, l2=l2_factor))(x)
    z=Sampling()([z_mean,z_logvar])
    encoder = keras.Model(inputs,[z_mean,z_logvar,z],name='encoder')
    return encoder

def Qmake_decoder_set_weights(input_dim,h_dim_1,h_dim_2,latent_dim):
    l2_factor = 1e-2
    inputs=keras.Input(shape=(latent_dim))
    x=layers.Dense(h_dim_2,
                   activation='relu',
                   kernel_initializer=keras.initializers.HeNormal(seed=None),
                   bias_initializer=keras.initializers.Zeros(),
                   kernel_regularizer=l1_l2(l1=0, l2=l2_factor))(inputs)
    x=BatchNormalization()(x)
    x=layers.Dense(h_dim_1,
                   activation='relu',
                   kernel_initializer=keras.initializers.HeNormal(seed=None),
                   bias_initializer=keras.initializers.Zeros(),
                   kernel_regularizer=l1_l2(l1=0, l2=l2_factor))(x)
    x=BatchNormalization()(x)
    z=layers.Dense(input_dim,
                   kernel_initializer=keras.initializers.HeNormal(seed=None),
                   bias_initializer=keras.initializers.Zeros(),
                   kernel_regularizer=l1_l2(l1=0, l2=l2_factor))(x)
    decoder=keras.Model(inputs,z,name='decoder')
    return decoder

def custom_mse_loss_with_multi_index_scaling(masked_data, masked_reconstruction):
#     jet_scale = 256/64
#     tau_scale = 128/64
#     muon_scale = 32/64
#     met_scale = 512/64
#     em_scale = 128/64
    jet_scale = 1
    tau_scale = 1
    muon_scale = 1
    met_scale = 1
    em_scale = 1
    # Define the indices and their corresponding scale factors
    scale_dict = {
        0: met_scale,
        3: em_scale, 6: em_scale, 9: em_scale, 12: em_scale,
        15: tau_scale, 18: tau_scale, 21: tau_scale, 24: tau_scale,
        27: jet_scale, 30: jet_scale, 33: jet_scale, 36: jet_scale, 39: jet_scale, 42: jet_scale,
        45: muon_scale, 48: muon_scale, 51: muon_scale, 54: muon_scale
    }

    # Create the scaling tensor
    scale_tensor = tf.ones_like(masked_data)
    for index, factor in scale_dict.items():
        index_mask = tf.one_hot(index, depth=tf.shape(masked_data)[-1])
        scale_tensor += index_mask * (factor - 1)

    # Apply scaling
    scaled_data = masked_data * scale_tensor
    scaled_reconstruction = masked_reconstruction * scale_tensor

    # Hardcoded lists for eta and phi indices
    eta_indices = [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55]
    phi_indices = [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56]

    batch_size = tf.shape(scaled_reconstruction)[0]
    
    # Set only the first eta (index 1) to zero
    indices = tf.stack([tf.range(batch_size), tf.ones(batch_size, dtype=tf.int32)], axis=1)
    updates = tf.zeros(batch_size)
    scaled_reconstruction = tf.tensor_scatter_nd_update(scaled_reconstruction, indices, updates)
    
#     # Apply constraints to eta
#     for i in eta_indices:
#         indices = tf.stack([tf.range(batch_size), tf.fill([batch_size], i)], axis=1)
#         updates = 3 * tf.tanh(scaled_reconstruction[:, i] / 3)
#         scaled_reconstruction = tf.tensor_scatter_nd_update(scaled_reconstruction, indices, updates)
    
#     # Apply constraints to phi
#     for i in phi_indices:
#         indices = tf.stack([tf.range(batch_size), tf.fill([batch_size], i)], axis=1)
#         updates = 3.14159265258979 * tf.tanh(scaled_reconstruction[:, i] / 3.14159265258979)
#         scaled_reconstruction = tf.tensor_scatter_nd_update(scaled_reconstruction, indices, updates)
        
    # Calculate MSE using keras.losses.mse
    mse = keras.losses.mse(scaled_data, scaled_reconstruction)

    # Take the sum across all dimensions
    return tf.reduce_sum(mse)

class VAE_Model(keras.Model):
    def __init__(self, encoder, decoder, steps_per_epoch=3125, cycle_length=10, min_beta=0.1, max_beta=0.85, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")
        self.beta_tracker = keras.metrics.Mean(name="beta")
        self.steps_per_epoch = steps_per_epoch
        self.cycle_length = tf.cast(cycle_length, tf.float32)
        self.min_beta = tf.cast(min_beta, tf.float32)
        self.max_beta = tf.cast(max_beta, tf.float32)
        self.beta = tf.Variable(min_beta, dtype=tf.float32)


    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
            self.beta_tracker,
        ]

    def cyclical_annealing_beta(self, epoch):
        cycle = tf.floor(1.0 + epoch / self.cycle_length)
        x = tf.abs(epoch / self.cycle_length - cycle + 1)
        return self.min_beta + (self.max_beta - self.min_beta) * tf.minimum(x, 1.0)
#     def set_beta(self,beta):
#         self.beta=beta

    def train_step(self, data):
        # Get the current epoch number
        epoch = tf.cast(self.optimizer.iterations / self.steps_per_epoch, tf.float32)
        
        # Update beta
        self.beta.assign(self.cyclical_annealing_beta(epoch))
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            mask = K.cast(K.not_equal(data, 0), K.floatx())
#             reconstruction_loss = tf.reduce_mean(keras.losses.mse(mask*data, mask*reconstruction))
            reconstruction_loss = custom_mse_loss_with_multi_index_scaling(mask*data, mask*reconstruction)
            reconstruction_loss *=(1-self.beta)

            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(kl_loss)
            kl_loss *=self.beta

            total_loss = reconstruction_loss + kl_loss
            
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reco_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
            "beta": self.beta,
        }

    def test_step(self, data):
        z_mean, z_log_var, z = self.encoder(data)
        reconstruction = self.decoder(z)
        mask = K.cast(K.not_equal(data, 0), K.floatx())
        reconstruction_loss = custom_mse_loss_with_multi_index_scaling(mask*data, mask*reconstruction)
#         reconstruction_loss = tf.reduce_mean(keras.losses.mse(mask*data, mask*reconstruction))
        reconstruction_loss*=(1-self.beta)

        kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
        kl_loss = tf.reduce_mean(kl_loss)        
        kl_loss *=self.beta
        
        total_loss = reconstruction_loss + kl_loss
        
        return {
            "loss": total_loss,
            "reco_loss": reconstruction_loss,
            "kl_loss": kl_loss,
            "beta": self.beta,
        }

    def call(self, data):
        z_mean,z_log_var,x = self.encoder(data)
        reconstruction = self.decoder(x)
        return {
            "z_mean": z_mean,
            "z_log_var": z_log_var,
            "reconstruction": reconstruction
        }

# %%
def weighted_mse(y_true, y_pred, sample_weight):
    return tf.reduce_mean(tf.multiply(sample_weight, tf.square(y_true - y_pred)))

# %%
NUM_EPOCHS = 100
BATCH_SIZE = 32768
STOP_PATIENCE = 20
LR_PATIENCE = 15

# %%
#TOPO 2A Trainer

T2A_enc = Qmake_encoder_set_weights(X_train.shape[1],512,256,48)
T2A_dec = Qmake_decoder_set_weights(X_train.shape[1],512,256,48)
steps_per_epoch = X_train.shape[0] // BATCH_SIZE
T2A = VAE_Model(T2A_enc, T2A_dec, steps_per_epoch=steps_per_epoch, cycle_length=10, min_beta=0.95, max_beta=0.95)
opt = keras.optimizers.Adam(learning_rate=0.001)
T2A.compile(optimizer=opt,weighted_metrics=[weighted_mse]) #,weighted_metrics=[weighted_mse]
# T2A.build(input_shape=(997315, 110))
T2A_enc.summary()
T2A_dec.summary()
# Out:
# 2024-10-06 20:21:00.482337: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 20:21:00.482884: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 20:21:00.483080: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 20:21:00.594136: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 20:21:00.594437: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 20:21:00.594676: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 20:21:00.594834: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:07.0, compute capability: 7.5
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  inputs (InputLayer)         [(None, 57)]                 0         []
#
#  dense1 (Dense)              (None, 512)                  29696     ['inputs[0][0]']
#
#  relu1 (ReLU)                (None, 512)                  0         ['dense1[0][0]']
#
#  dense2 (Dense)              (None, 256)                  131328    ['relu1[0][0]']
#
#  relu2 (ReLU)                (None, 256)                  0         ['dense2[0][0]']
#
#  z_mean (Dense)              (None, 48)                   12336     ['relu2[0][0]']
#
#  z_log_var (Dense)           (None, 48)                   12336     ['relu2[0][0]']
#
#  sampling (Sampling)         (None, 48)                   0         ['z_mean[0][0]',
#                                                                      'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 185696 (725.38 KB)
# Trainable params: 185696 (725.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48)]              0
#
#  dense (Dense)               (None, 256)               12544
#
#  batch_normalization (Batch  (None, 256)               1024
#  Normalization)
#
#  dense_1 (Dense)             (None, 512)               131584
#
#  batch_normalization_1 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dense_2 (Dense)             (None, 57)                29241
#
# =================================================================
# Total params: 176441 (689.22 KB)
# Trainable params: 174905 (683.22 KB)
# Non-trainable params: 1536 (6.00 KB)
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(patience=STOP_PATIENCE, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=LR_PATIENCE, verbose=1)

callbacks = [early_stopping, reduce_lr]

tf.keras.backend.clear_session()
history = T2A.fit(x=X_train, validation_split=0.2, epochs=NUM_EPOCHS, batch_size=BATCH_SIZE, callbacks=callbacks, shuffle=True)
T2A.save_weights(filepath='/eos/user/h/hjia/ToyVAE/software_dev/software_model/checkpoint_512_256_48/', save_format='tf')
# Out:
# Epoch 1/100
# 2024-10-06 20:21:07.381253: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f9d19628660 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-10-06 20:21:07.381323: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2024-10-06 20:21:07.399921: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-06 20:21:07.497539: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2024-10-06 20:21:07.883925: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 79/79 [==============================] - 11s 56ms/step - loss: 2921.5259 - reco_loss: 2920.4656 - kl_loss: 1.6005 - beta: 0.9504 - val_loss: 353.0206 - val_reco_loss: 350.3517 - val_kl_loss: 2.6688 - val_beta: 0.9504 - lr: 0.0010
# Epoch 2/100
# 79/79 [==============================] - 3s 42ms/step - loss: 713.0363 - reco_loss: 709.3729 - kl_loss: 4.2080 - beta: 0.9503 - val_loss: 182.9184 - val_reco_loss: 178.7170 - val_kl_loss: 4.2014 - val_beta: 0.9503 - lr: 0.0010
# Epoch 3/100
# 79/79 [==============================] - 3s 43ms/step - loss: 432.2846 - reco_loss: 427.3324 - kl_loss: 5.0942 - beta: 0.9502 - val_loss: 125.7075 - val_reco_loss: 121.2287 - val_kl_loss: 4.4789 - val_beta: 0.9502 - lr: 0.0010
# Epoch 4/100
# 79/79 [==============================] - 3s 43ms/step - loss: 270.5734 - reco_loss: 265.4078 - kl_loss: 5.3914 - beta: 0.9502 - val_loss: 104.7582 - val_reco_loss: 99.7663 - val_kl_loss: 4.9919 - val_beta: 0.9502 - lr: 0.0010
# Epoch 5/100
# 79/79 [==============================] - 3s 43ms/step - loss: 205.5079 - reco_loss: 199.9357 - kl_loss: 5.7066 - beta: 0.9502 - val_loss: 88.1067 - val_reco_loss: 82.9676 - val_kl_loss: 5.1391 - val_beta: 0.9502 - lr: 0.0010
# Epoch 6/100
# 79/79 [==============================] - 3s 43ms/step - loss: 184.1381 - reco_loss: 178.3576 - kl_loss: 5.8176 - beta: 0.9502 - val_loss: 73.6336 - val_reco_loss: 68.4641 - val_kl_loss: 5.1695 - val_beta: 0.9502 - lr: 0.0010
# Epoch 7/100
# 79/79 [==============================] - 3s 43ms/step - loss: 160.0076 - reco_loss: 154.2624 - kl_loss: 5.8059 - beta: 0.9502 - val_loss: 62.1569 - val_reco_loss: 56.9207 - val_kl_loss: 5.2362 - val_beta: 0.9502 - lr: 0.0010
# Epoch 8/100
# 79/79 [==============================] - 3s 43ms/step - loss: 143.9713 - reco_loss: 138.1789 - kl_loss: 5.8006 - beta: 0.9502 - val_loss: 54.9883 - val_reco_loss: 49.7423 - val_kl_loss: 5.2460 - val_beta: 0.9502 - lr: 0.0010
# Epoch 9/100
# 79/79 [==============================] - 3s 43ms/step - loss: 109.5548 - reco_loss: 103.7765 - kl_loss: 5.8683 - beta: 0.9502 - val_loss: 54.7082 - val_reco_loss: 49.3868 - val_kl_loss: 5.3213 - val_beta: 0.9502 - lr: 0.0010
# Epoch 10/100
# 79/79 [==============================] - 3s 43ms/step - loss: 139.5017 - reco_loss: 133.6847 - kl_loss: 5.9085 - beta: 0.9502 - val_loss: 47.8883 - val_reco_loss: 42.7093 - val_kl_loss: 5.1790 - val_beta: 0.9502 - lr: 0.0010
# Epoch 11/100
# 79/79 [==============================] - 3s 43ms/step - loss: 92.9663 - reco_loss: 87.2734 - kl_loss: 5.8638 - beta: 0.9502 - val_loss: 41.6206 - val_reco_loss: 36.3155 - val_kl_loss: 5.3051 - val_beta: 0.9502 - lr: 0.0010
# Epoch 12/100
# 79/79 [==============================] - 3s 44ms/step - loss: 78.4184 - reco_loss: 72.6199 - kl_loss: 5.8856 - beta: 0.9501 - val_loss: 41.5139 - val_reco_loss: 36.1723 - val_kl_loss: 5.3416 - val_beta: 0.9501 - lr: 0.0010
# Epoch 13/100
# 79/79 [==============================] - 3s 44ms/step - loss: 76.4195 - reco_loss: 70.5693 - kl_loss: 5.9303 - beta: 0.9501 - val_loss: 36.7821 - val_reco_loss: 31.4078 - val_kl_loss: 5.3742 - val_beta: 0.9501 - lr: 0.0010
# Epoch 14/100
# 79/79 [==============================] - 3s 44ms/step - loss: 67.0229 - reco_loss: 61.2380 - kl_loss: 5.8456 - beta: 0.9502 - val_loss: 38.9353 - val_reco_loss: 33.6926 - val_kl_loss: 5.2427 - val_beta: 0.9502 - lr: 0.0010
# Epoch 15/100
# 79/79 [==============================] - 3s 44ms/step - loss: 79.2042 - reco_loss: 73.3966 - kl_loss: 5.7591 - beta: 0.9501 - val_loss: 31.9876 - val_reco_loss: 26.8145 - val_kl_loss: 5.1731 - val_beta: 0.9501 - lr: 0.0010
# Epoch 16/100
# 79/79 [==============================] - 3s 44ms/step - loss: 76.2974 - reco_loss: 70.5537 - kl_loss: 5.7093 - beta: 0.9501 - val_loss: 30.3762 - val_reco_loss: 25.1237 - val_kl_loss: 5.2525 - val_beta: 0.9501 - lr: 0.0010
# Epoch 17/100
# 79/79 [==============================] - 3s 44ms/step - loss: 60.8722 - reco_loss: 55.2055 - kl_loss: 5.7023 - beta: 0.9501 - val_loss: 30.5629 - val_reco_loss: 25.3857 - val_kl_loss: 5.1772 - val_beta: 0.9501 - lr: 0.0010
# Epoch 18/100
# 79/79 [==============================] - 3s 44ms/step - loss: 66.1170 - reco_loss: 60.4094 - kl_loss: 5.6561 - beta: 0.9501 - val_loss: 29.3853 - val_reco_loss: 24.1374 - val_kl_loss: 5.2479 - val_beta: 0.9501 - lr: 0.0010
# Epoch 19/100
# 79/79 [==============================] - 3s 44ms/step - loss: 81.8748 - reco_loss: 76.4153 - kl_loss: 5.4289 - beta: 0.9502 - val_loss: 33.0945 - val_reco_loss: 28.0052 - val_kl_loss: 5.0893 - val_beta: 0.9502 - lr: 0.0010
# Epoch 20/100
# 79/79 [==============================] - 3s 44ms/step - loss: 93.4028 - reco_loss: 87.8446 - kl_loss: 5.4999 - beta: 0.9501 - val_loss: 25.9040 - val_reco_loss: 20.8886 - val_kl_loss: 5.0154 - val_beta: 0.9501 - lr: 0.0010
# Epoch 21/100
# 79/79 [==============================] - 3s 44ms/step - loss: 99.9568 - reco_loss: 94.2850 - kl_loss: 5.8761 - beta: 0.9502 - val_loss: 31.7492 - val_reco_loss: 26.3750 - val_kl_loss: 5.3742 - val_beta: 0.9502 - lr: 0.0010
# Epoch 22/100
# 79/79 [==============================] - 3s 44ms/step - loss: 138.9927 - reco_loss: 133.2748 - kl_loss: 5.6064 - beta: 0.9502 - val_loss: 30.1274 - val_reco_loss: 25.1506 - val_kl_loss: 4.9768 - val_beta: 0.9502 - lr: 0.0010
# Epoch 23/100
# 79/79 [==============================] - 4s 45ms/step - loss: 95.1337 - reco_loss: 89.6166 - kl_loss: 5.5767 - beta: 0.9502 - val_loss: 26.3795 - val_reco_loss: 21.1502 - val_kl_loss: 5.2293 - val_beta: 0.9502 - lr: 0.0010
# Epoch 24/100
# 79/79 [==============================] - 3s 44ms/step - loss: 63.4293 - reco_loss: 57.7840 - kl_loss: 5.6307 - beta: 0.9501 - val_loss: 25.7056 - val_reco_loss: 20.5686 - val_kl_loss: 5.1369 - val_beta: 0.9501 - lr: 0.0010
# Epoch 25/100
# 79/79 [==============================] - 3s 44ms/step - loss: 65.4042 - reco_loss: 59.8015 - kl_loss: 5.5288 - beta: 0.9501 - val_loss: 21.6792 - val_reco_loss: 16.6693 - val_kl_loss: 5.0099 - val_beta: 0.9501 - lr: 0.0010
# Epoch 26/100
# 79/79 [==============================] - 3s 44ms/step - loss: 77.5344 - reco_loss: 72.0431 - kl_loss: 5.5040 - beta: 0.9501 - val_loss: 22.4601 - val_reco_loss: 17.4576 - val_kl_loss: 5.0025 - val_beta: 0.9501 - lr: 0.0010
# Epoch 27/100
# 79/79 [==============================] - 3s 44ms/step - loss: 54.4582 - reco_loss: 49.0056 - kl_loss: 5.4102 - beta: 0.9502 - val_loss: 25.4675 - val_reco_loss: 20.7237 - val_kl_loss: 4.7438 - val_beta: 0.9502 - lr: 0.0010
# Epoch 28/100
# 79/79 [==============================] - 3s 44ms/step - loss: 94.2370 - reco_loss: 88.8513 - kl_loss: 5.3997 - beta: 0.9501 - val_loss: 19.8512 - val_reco_loss: 14.8407 - val_kl_loss: 5.0105 - val_beta: 0.9501 - lr: 0.0010
# Epoch 29/100
# 79/79 [==============================] - 3s 44ms/step - loss: 40.8071 - reco_loss: 35.3526 - kl_loss: 5.4449 - beta: 0.9501 - val_loss: 19.8848 - val_reco_loss: 14.9677 - val_kl_loss: 4.9171 - val_beta: 0.9501 - lr: 0.0010
# Epoch 30/100
# 79/79 [==============================] - 3s 44ms/step - loss: 33.6104 - reco_loss: 28.2723 - kl_loss: 5.3803 - beta: 0.9501 - val_loss: 18.0823 - val_reco_loss: 13.1385 - val_kl_loss: 4.9438 - val_beta: 0.9501 - lr: 0.0010
# Epoch 31/100
# 79/79 [==============================] - 4s 45ms/step - loss: 38.0820 - reco_loss: 32.7241 - kl_loss: 5.3371 - beta: 0.9501 - val_loss: 17.2184 - val_reco_loss: 12.3072 - val_kl_loss: 4.9112 - val_beta: 0.9501 - lr: 0.0010
# Epoch 32/100
# 79/79 [==============================] - 4s 45ms/step - loss: 35.6271 - reco_loss: 30.3018 - kl_loss: 5.3222 - beta: 0.9501 - val_loss: 17.9865 - val_reco_loss: 13.1551 - val_kl_loss: 4.8314 - val_beta: 0.9501 - lr: 0.0010
# Epoch 33/100
# 79/79 [==============================] - 4s 45ms/step - loss: 42.1713 - reco_loss: 36.9203 - kl_loss: 5.1922 - beta: 0.9501 - val_loss: 16.8886 - val_reco_loss: 12.1410 - val_kl_loss: 4.7476 - val_beta: 0.9501 - lr: 0.0010
# Epoch 34/100
# 79/79 [==============================] - 3s 44ms/step - loss: 44.9564 - reco_loss: 39.7569 - kl_loss: 5.1851 - beta: 0.9501 - val_loss: 17.4998 - val_reco_loss: 12.7534 - val_kl_loss: 4.7464 - val_beta: 0.9501 - lr: 0.0010
# Epoch 35/100
# 79/79 [==============================] - 4s 44ms/step - loss: 46.4726 - reco_loss: 41.3612 - kl_loss: 5.0987 - beta: 0.9501 - val_loss: 18.5586 - val_reco_loss: 13.9652 - val_kl_loss: 4.5934 - val_beta: 0.9501 - lr: 0.0010
# Epoch 36/100
# 79/79 [==============================] - 4s 45ms/step - loss: 49.8013 - reco_loss: 44.6904 - kl_loss: 5.0811 - beta: 0.9501 - val_loss: 15.8346 - val_reco_loss: 11.1341 - val_kl_loss: 4.7005 - val_beta: 0.9501 - lr: 0.0010
# Epoch 37/100
# 79/79 [==============================] - 4s 45ms/step - loss: 31.6608 - reco_loss: 26.5919 - kl_loss: 5.0934 - beta: 0.9501 - val_loss: 15.7788 - val_reco_loss: 11.0830 - val_kl_loss: 4.6958 - val_beta: 0.9501 - lr: 0.0010
# Epoch 38/100
# 79/79 [==============================] - 4s 45ms/step - loss: 27.7393 - reco_loss: 22.6978 - kl_loss: 5.0566 - beta: 0.9501 - val_loss: 15.7191 - val_reco_loss: 11.1016 - val_kl_loss: 4.6175 - val_beta: 0.9501 - lr: 0.0010
# Epoch 39/100
# 79/79 [==============================] - 3s 44ms/step - loss: 28.7153 - reco_loss: 23.7260 - kl_loss: 4.9957 - beta: 0.9501 - val_loss: 15.1002 - val_reco_loss: 10.5290 - val_kl_loss: 4.5712 - val_beta: 0.9501 - lr: 0.0010
# Epoch 40/100
# 79/79 [==============================] - 3s 44ms/step - loss: 30.7715 - reco_loss: 25.8310 - kl_loss: 4.9605 - beta: 0.9502 - val_loss: 16.9452 - val_reco_loss: 12.3495 - val_kl_loss: 4.5957 - val_beta: 0.9502 - lr: 0.0010
# Epoch 41/100
# 79/79 [==============================] - 3s 44ms/step - loss: 32.4091 - reco_loss: 27.4580 - kl_loss: 4.9153 - beta: 0.9502 - val_loss: 17.1085 - val_reco_loss: 12.6123 - val_kl_loss: 4.4963 - val_beta: 0.9502 - lr: 0.0010
# Epoch 42/100
# 79/79 [==============================] - 3s 44ms/step - loss: 31.6485 - reco_loss: 26.7681 - kl_loss: 4.8831 - beta: 0.9502 - val_loss: 16.2069 - val_reco_loss: 11.7378 - val_kl_loss: 4.4691 - val_beta: 0.9502 - lr: 0.0010
# Epoch 43/100
# 79/79 [==============================] - 3s 44ms/step - loss: 32.7663 - reco_loss: 28.0338 - kl_loss: 4.7709 - beta: 0.9502 - val_loss: 18.6161 - val_reco_loss: 14.1262 - val_kl_loss: 4.4899 - val_beta: 0.9502 - lr: 0.0010
# Epoch 44/100
# 79/79 [==============================] - 3s 44ms/step - loss: 43.4085 - reco_loss: 38.6600 - kl_loss: 4.7635 - beta: 0.9502 - val_loss: 17.1254 - val_reco_loss: 12.8373 - val_kl_loss: 4.2881 - val_beta: 0.9502 - lr: 0.0010
# Epoch 45/100
# 79/79 [==============================] - 3s 44ms/step - loss: 44.3522 - reco_loss: 39.6156 - kl_loss: 4.7381 - beta: 0.9502 - val_loss: 15.2394 - val_reco_loss: 10.9249 - val_kl_loss: 4.3145 - val_beta: 0.9502 - lr: 0.0010
# Epoch 46/100
# 79/79 [==============================] - 4s 45ms/step - loss: 57.8329 - reco_loss: 53.1083 - kl_loss: 4.7076 - beta: 0.9502 - val_loss: 16.9870 - val_reco_loss: 12.5401 - val_kl_loss: 4.4469 - val_beta: 0.9502 - lr: 0.0010
# Epoch 47/100
# 79/79 [==============================] - 4s 45ms/step - loss: 37.3922 - reco_loss: 32.6954 - kl_loss: 4.6250 - beta: 0.9504 - val_loss: 19.5195 - val_reco_loss: 15.2104 - val_kl_loss: 4.3091 - val_beta: 0.9504 - lr: 0.0010
# Epoch 48/100
# 79/79 [==============================] - 3s 44ms/step - loss: 52.2246 - reco_loss: 47.5672 - kl_loss: 4.6817 - beta: 0.9503 - val_loss: 18.5649 - val_reco_loss: 14.2836 - val_kl_loss: 4.2813 - val_beta: 0.9503 - lr: 0.0010
# Epoch 49/100
# 79/79 [==============================] - 3s 44ms/step - loss: 39.6190 - reco_loss: 35.0547 - kl_loss: 4.6031 - beta: 0.9503 - val_loss: 17.9354 - val_reco_loss: 13.5682 - val_kl_loss: 4.3673 - val_beta: 0.9503 - lr: 0.0010
# Epoch 50/100
# 79/79 [==============================] - 3s 44ms/step - loss: 34.5644 - reco_loss: 29.9463 - kl_loss: 4.6234 - beta: 0.9503 - val_loss: 17.1193 - val_reco_loss: 12.9819 - val_kl_loss: 4.1374 - val_beta: 0.9503 - lr: 0.0010
# Epoch 51/100
# 79/79 [==============================] - 4s 45ms/step - loss: 41.7224 - reco_loss: 37.2340 - kl_loss: 4.5733 - beta: 0.9502 - val_loss: 14.6714 - val_reco_loss: 10.2717 - val_kl_loss: 4.3997 - val_beta: 0.9502 - lr: 0.0010
# Epoch 52/100
# 79/79 [==============================] - 3s 44ms/step - loss: 49.9784 - reco_loss: 45.3930 - kl_loss: 4.5407 - beta: 0.9504 - val_loss: 21.4698 - val_reco_loss: 17.4652 - val_kl_loss: 4.0047 - val_beta: 0.9504 - lr: 0.0010
# Epoch 53/100
# 79/79 [==============================] - 3s 44ms/step - loss: 60.5487 - reco_loss: 56.1126 - kl_loss: 4.4628 - beta: 0.9503 - val_loss: 17.0846 - val_reco_loss: 12.9210 - val_kl_loss: 4.1637 - val_beta: 0.9503 - lr: 0.0010
# Epoch 54/100
# 79/79 [==============================] - 3s 44ms/step - loss: 57.1030 - reco_loss: 52.6025 - kl_loss: 4.5563 - beta: 0.9507 - val_loss: 15.6874 - val_reco_loss: 11.4155 - val_kl_loss: 4.2719 - val_beta: 0.9507 - lr: 0.0010
# Epoch 55/100
# 79/79 [==============================] - 3s 44ms/step - loss: 48.6295 - reco_loss: 44.1616 - kl_loss: 4.4522 - beta: 0.9503 - val_loss: 16.7877 - val_reco_loss: 12.5588 - val_kl_loss: 4.2289 - val_beta: 0.9503 - lr: 0.0010
# Epoch 56/100
# 79/79 [==============================] - 3s 44ms/step - loss: 50.6011 - reco_loss: 46.1024 - kl_loss: 4.5157 - beta: 0.9504 - val_loss: 20.3177 - val_reco_loss: 16.1802 - val_kl_loss: 4.1375 - val_beta: 0.9504 - lr: 0.0010
# Epoch 57/100
# 79/79 [==============================] - 4s 44ms/step - loss: 60.0346 - reco_loss: 55.6296 - kl_loss: 4.4200 - beta: 0.9502 - val_loss: 13.9412 - val_reco_loss: 9.7601 - val_kl_loss: 4.1811 - val_beta: 0.9502 - lr: 0.0010
# Epoch 58/100
# 79/79 [==============================] - 4s 44ms/step - loss: 48.2088 - reco_loss: 43.8394 - kl_loss: 4.4124 - beta: 0.9502 - val_loss: 15.1809 - val_reco_loss: 11.0327 - val_kl_loss: 4.1482 - val_beta: 0.9502 - lr: 0.0010
# Epoch 59/100
# 79/79 [==============================] - 3s 44ms/step - loss: 43.6632 - reco_loss: 39.2010 - kl_loss: 4.4581 - beta: 0.9502 - val_loss: 12.7916 - val_reco_loss: 8.6217 - val_kl_loss: 4.1699 - val_beta: 0.9502 - lr: 0.0010
# Epoch 60/100
# 79/79 [==============================] - 3s 44ms/step - loss: 51.8103 - reco_loss: 47.4033 - kl_loss: 4.4052 - beta: 0.9502 - val_loss: 13.4766 - val_reco_loss: 9.4002 - val_kl_loss: 4.0763 - val_beta: 0.9502 - lr: 0.0010
# Epoch 61/100
# 79/79 [==============================] - 3s 44ms/step - loss: 41.7032 - reco_loss: 37.3461 - kl_loss: 4.3760 - beta: 0.9503 - val_loss: 17.4742 - val_reco_loss: 13.4789 - val_kl_loss: 3.9953 - val_beta: 0.9503 - lr: 0.0010
# Epoch 62/100
# 79/79 [==============================] - 3s 44ms/step - loss: 28.8106 - reco_loss: 24.5528 - kl_loss: 4.3121 - beta: 0.9503 - val_loss: 13.8608 - val_reco_loss: 9.7777 - val_kl_loss: 4.0831 - val_beta: 0.9503 - lr: 0.0010
# Epoch 63/100
# 79/79 [==============================] - 3s 44ms/step - loss: 27.6856 - reco_loss: 23.3954 - kl_loss: 4.2727 - beta: 0.9503 - val_loss: 13.4047 - val_reco_loss: 9.3612 - val_kl_loss: 4.0435 - val_beta: 0.9503 - lr: 0.0010
# Epoch 64/100
# 79/79 [==============================] - 3s 44ms/step - loss: 33.4623 - reco_loss: 29.1729 - kl_loss: 4.2990 - beta: 0.9503 - val_loss: 12.2578 - val_reco_loss: 8.2360 - val_kl_loss: 4.0218 - val_beta: 0.9503 - lr: 0.0010
# Epoch 65/100
# 79/79 [==============================] - 4s 44ms/step - loss: 26.2866 - reco_loss: 21.9789 - kl_loss: 4.2828 - beta: 0.9501 - val_loss: 11.0675 - val_reco_loss: 7.0466 - val_kl_loss: 4.0209 - val_beta: 0.9501 - lr: 0.0010
# Epoch 66/100
# 79/79 [==============================] - 3s 44ms/step - loss: 21.7136 - reco_loss: 17.4451 - kl_loss: 4.2709 - beta: 0.9502 - val_loss: 11.2960 - val_reco_loss: 7.2989 - val_kl_loss: 3.9971 - val_beta: 0.9502 - lr: 0.0010
# Epoch 67/100
# 79/79 [==============================] - 4s 45ms/step - loss: 30.2989 - reco_loss: 26.0516 - kl_loss: 4.2166 - beta: 0.9502 - val_loss: 10.9604 - val_reco_loss: 7.0124 - val_kl_loss: 3.9481 - val_beta: 0.9502 - lr: 0.0010
# Epoch 68/100
# 79/79 [==============================] - 4s 45ms/step - loss: 45.6297 - reco_loss: 41.3806 - kl_loss: 4.1951 - beta: 0.9502 - val_loss: 12.1209 - val_reco_loss: 8.0822 - val_kl_loss: 4.0388 - val_beta: 0.9502 - lr: 0.0010
# Epoch 69/100
# 79/79 [==============================] - 3s 44ms/step - loss: 21.4524 - reco_loss: 17.2714 - kl_loss: 4.1987 - beta: 0.9502 - val_loss: 12.8392 - val_reco_loss: 8.9151 - val_kl_loss: 3.9241 - val_beta: 0.9502 - lr: 0.0010
# Epoch 70/100
# 79/79 [==============================] - 3s 44ms/step - loss: 27.3990 - reco_loss: 23.1903 - kl_loss: 4.1871 - beta: 0.9502 - val_loss: 12.3555 - val_reco_loss: 8.3560 - val_kl_loss: 3.9995 - val_beta: 0.9502 - lr: 0.0010
# Epoch 71/100
# 79/79 [==============================] - 3s 44ms/step - loss: 25.5938 - reco_loss: 21.4723 - kl_loss: 4.1360 - beta: 0.9502 - val_loss: 11.2891 - val_reco_loss: 7.4896 - val_kl_loss: 3.7995 - val_beta: 0.9502 - lr: 0.0010
# Epoch 72/100
# 79/79 [==============================] - 3s 44ms/step - loss: 34.5761 - reco_loss: 30.4253 - kl_loss: 4.1244 - beta: 0.9502 - val_loss: 12.1789 - val_reco_loss: 8.3804 - val_kl_loss: 3.7985 - val_beta: 0.9502 - lr: 0.0010
# Epoch 73/100
# 79/79 [==============================] - 3s 44ms/step - loss: 25.6271 - reco_loss: 21.5600 - kl_loss: 4.0983 - beta: 0.9503 - val_loss: 11.5292 - val_reco_loss: 7.6315 - val_kl_loss: 3.8977 - val_beta: 0.9503 - lr: 0.0010
# Epoch 74/100
# 79/79 [==============================] - 3s 44ms/step - loss: 26.9557 - reco_loss: 22.8849 - kl_loss: 4.0887 - beta: 0.9503 - val_loss: 13.1665 - val_reco_loss: 9.2910 - val_kl_loss: 3.8754 - val_beta: 0.9503 - lr: 0.0010
# Epoch 75/100
# 79/79 [==============================] - 3s 44ms/step - loss: 39.0354 - reco_loss: 34.9470 - kl_loss: 4.0430 - beta: 0.9504 - val_loss: 15.7040 - val_reco_loss: 11.8654 - val_kl_loss: 3.8386 - val_beta: 0.9504 - lr: 0.0010
# Epoch 76/100
# 79/79 [==============================] - 3s 44ms/step - loss: 33.6490 - reco_loss: 29.6502 - kl_loss: 4.0465 - beta: 0.9503 - val_loss: 13.7764 - val_reco_loss: 9.9548 - val_kl_loss: 3.8216 - val_beta: 0.9503 - lr: 0.0010
# Epoch 77/100
# 79/79 [==============================] - 4s 45ms/step - loss: 32.0226 - reco_loss: 27.9819 - kl_loss: 4.0405 - beta: 0.9504 - val_loss: 12.4720 - val_reco_loss: 8.8009 - val_kl_loss: 3.6711 - val_beta: 0.9504 - lr: 0.0010
# Epoch 78/100
# 79/79 [==============================] - 4s 44ms/step - loss: 23.5470 - reco_loss: 19.5465 - kl_loss: 4.0097 - beta: 0.9502 - val_loss: 11.5669 - val_reco_loss: 7.8294 - val_kl_loss: 3.7375 - val_beta: 0.9502 - lr: 0.0010
# Epoch 79/100
# 79/79 [==============================] - 3s 44ms/step - loss: 24.5087 - reco_loss: 20.5112 - kl_loss: 4.0322 - beta: 0.9503 - val_loss: 10.5412 - val_reco_loss: 6.6519 - val_kl_loss: 3.8892 - val_beta: 0.9503 - lr: 0.0010
# Epoch 80/100
# 79/79 [==============================] - 3s 44ms/step - loss: 21.9493 - reco_loss: 17.9192 - kl_loss: 4.0122 - beta: 0.9505 - val_loss: 11.6886 - val_reco_loss: 7.8057 - val_kl_loss: 3.8829 - val_beta: 0.9505 - lr: 0.0010
# Epoch 81/100
# 79/79 [==============================] - 3s 43ms/step - loss: 26.8529 - reco_loss: 22.8151 - kl_loss: 3.9930 - beta: 0.9502 - val_loss: 10.7929 - val_reco_loss: 7.0029 - val_kl_loss: 3.7900 - val_beta: 0.9502 - lr: 0.0010
# Epoch 82/100
# 79/79 [==============================] - 3s 44ms/step - loss: 27.0201 - reco_loss: 22.9812 - kl_loss: 3.9835 - beta: 0.9503 - val_loss: 11.0923 - val_reco_loss: 7.3624 - val_kl_loss: 3.7299 - val_beta: 0.9503 - lr: 0.0010
# Epoch 83/100
# 79/79 [==============================] - 3s 44ms/step - loss: 24.4507 - reco_loss: 20.4504 - kl_loss: 3.9727 - beta: 0.9503 - val_loss: 10.4817 - val_reco_loss: 6.7560 - val_kl_loss: 3.7257 - val_beta: 0.9503 - lr: 0.0010
# Epoch 84/100
# 79/79 [==============================] - 3s 44ms/step - loss: 27.0781 - reco_loss: 23.1320 - kl_loss: 3.9575 - beta: 0.9505 - val_loss: 14.0738 - val_reco_loss: 10.4208 - val_kl_loss: 3.6529 - val_beta: 0.9505 - lr: 0.0010
# Epoch 85/100
# 79/79 [==============================] - 3s 44ms/step - loss: 29.9131 - reco_loss: 26.0407 - kl_loss: 3.9509 - beta: 0.9506 - val_loss: 15.3591 - val_reco_loss: 11.6437 - val_kl_loss: 3.7154 - val_beta: 0.9506 - lr: 0.0010
# Epoch 86/100
# 79/79 [==============================] - 4s 44ms/step - loss: 63.7714 - reco_loss: 59.7998 - kl_loss: 3.9309 - beta: 0.9506 - val_loss: 14.7865 - val_reco_loss: 11.0907 - val_kl_loss: 3.6958 - val_beta: 0.9506 - lr: 0.0010
# Epoch 87/100
# 79/79 [==============================] - 3s 44ms/step - loss: 43.0745 - reco_loss: 39.2019 - kl_loss: 3.9030 - beta: 0.9507 - val_loss: 14.9833 - val_reco_loss: 11.3153 - val_kl_loss: 3.6679 - val_beta: 0.9507 - lr: 0.0010
# Epoch 88/100
# 79/79 [==============================] - 3s 44ms/step - loss: 34.3645 - reco_loss: 30.5040 - kl_loss: 3.9072 - beta: 0.9507 - val_loss: 17.4154 - val_reco_loss: 13.7504 - val_kl_loss: 3.6650 - val_beta: 0.9507 - lr: 0.0010
# Epoch 89/100
# 79/79 [==============================] - 3s 44ms/step - loss: 38.0570 - reco_loss: 34.2645 - kl_loss: 3.9328 - beta: 0.9504 - val_loss: 12.5913 - val_reco_loss: 8.9311 - val_kl_loss: 3.6602 - val_beta: 0.9504 - lr: 0.0010
# Epoch 90/100
# 79/79 [==============================] - 3s 44ms/step - loss: 21.5609 - reco_loss: 17.6820 - kl_loss: 3.9036 - beta: 0.9503 - val_loss: 11.6556 - val_reco_loss: 7.9965 - val_kl_loss: 3.6591 - val_beta: 0.9503 - lr: 0.0010
# Epoch 91/100
# 79/79 [==============================] - 3s 44ms/step - loss: 21.3677 - reco_loss: 17.4990 - kl_loss: 3.8685 - beta: 0.9503 - val_loss: 9.7447 - val_reco_loss: 6.1456 - val_kl_loss: 3.5991 - val_beta: 0.9503 - lr: 0.0010
# Epoch 92/100
# 79/79 [==============================] - 3s 44ms/step - loss: 19.7412 - reco_loss: 15.8758 - kl_loss: 3.8853 - beta: 0.9506 - val_loss: 14.3039 - val_reco_loss: 10.7400 - val_kl_loss: 3.5639 - val_beta: 0.9506 - lr: 0.0010
# Epoch 93/100
# 79/79 [==============================] - 3s 44ms/step - loss: 33.6124 - reco_loss: 29.7781 - kl_loss: 3.8690 - beta: 0.9506 - val_loss: 14.2681 - val_reco_loss: 10.5887 - val_kl_loss: 3.6794 - val_beta: 0.9506 - lr: 0.0010
# Epoch 94/100
# 79/79 [==============================] - 3s 44ms/step - loss: 30.9125 - reco_loss: 27.0407 - kl_loss: 3.8601 - beta: 0.9503 - val_loss: 10.7135 - val_reco_loss: 7.1315 - val_kl_loss: 3.5820 - val_beta: 0.9503 - lr: 0.0010
# Epoch 95/100
# 79/79 [==============================] - 3s 44ms/step - loss: 49.2024 - reco_loss: 45.3712 - kl_loss: 3.8349 - beta: 0.9504 - val_loss: 12.5690 - val_reco_loss: 8.9951 - val_kl_loss: 3.5739 - val_beta: 0.9504 - lr: 0.0010
# Epoch 96/100
# 79/79 [==============================] - 3s 44ms/step - loss: 32.1004 - reco_loss: 28.2747 - kl_loss: 3.8388 - beta: 0.9503 - val_loss: 10.7264 - val_reco_loss: 7.1564 - val_kl_loss: 3.5700 - val_beta: 0.9503 - lr: 0.0010
# Epoch 97/100
# 79/79 [==============================] - 3s 44ms/step - loss: 26.9121 - reco_loss: 23.0899 - kl_loss: 3.9038 - beta: 0.9503 - val_loss: 11.8424 - val_reco_loss: 8.2765 - val_kl_loss: 3.5659 - val_beta: 0.9503 - lr: 0.0010
# Epoch 98/100
# 79/79 [==============================] - 4s 44ms/step - loss: 19.8314 - reco_loss: 16.0135 - kl_loss: 3.8851 - beta: 0.9502 - val_loss: 9.8991 - val_reco_loss: 6.2317 - val_kl_loss: 3.6674 - val_beta: 0.9502 - lr: 0.0010
# Epoch 99/100
# 79/79 [==============================] - 3s 44ms/step - loss: 18.5549 - reco_loss: 14.6251 - kl_loss: 3.9047 - beta: 0.9502 - val_loss: 8.9219 - val_reco_loss: 5.2620 - val_kl_loss: 3.6599 - val_beta: 0.9502 - lr: 0.0010
# Epoch 100/100
# 79/79 [==============================] - 3s 44ms/step - loss: 15.2854 - reco_loss: 11.4545 - kl_loss: 3.8437 - beta: 0.9502 - val_loss: 9.6126 - val_reco_loss: 6.0144 - val_kl_loss: 3.5982 - val_beta: 0.9502 - lr: 0.0010

# %%
import matplotlib.pyplot as plt

# Assuming 'history' is the object returned by your model.fit() call

# Extract the loss values
total_loss = history.history['loss']
reco_loss = history.history['reco_loss']
kl_loss = history.history['kl_loss']
val_total_loss = history.history['val_loss']
val_reco_loss = history.history['val_reco_loss']
val_kl_loss = history.history['val_kl_loss']

# Create a new figure
plt.figure(figsize=(12, 8))

# Plot training losses
plt.plot(total_loss, label='Total Loss', color='blue')
plt.plot(reco_loss, label='Reconstruction Loss', color='green')
plt.plot(kl_loss, label='KL Loss', color='red')

# Plot validation losses
plt.plot(val_total_loss, label='Val Total Loss', color='blue', linestyle='--')
plt.plot(val_reco_loss, label='Val Reconstruction Loss', color='green', linestyle='--')
plt.plot(val_kl_loss, label='Val KL Loss', color='red', linestyle='--')

# Customize the plot
plt.title('Training and Validation Losses')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale("log")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# # Repeat testing
# for i in range(0,20):
#     T2A_enc = Qmake_encoder_set_weights(X_train.shape[1],512,256,48)
#     T2A_dec = Qmake_decoder_set_weights(X_train.shape[1],512,256,48)
#     steps_per_epoch = X_train.shape[0] // BATCH_SIZE
#     T2A = VAE_Model(T2A_enc, T2A_dec, steps_per_epoch=steps_per_epoch, cycle_length=10, min_beta=0.1, max_beta=0.7)
#     # T2A.set_beta(beta)
#     opt = keras.optimizers.Adam(learning_rate=0.001)
#     T2A.compile(optimizer=opt,weighted_metrics=[weighted_mse]) #,weighted_metrics=[weighted_mse]

#     early_stopping = EarlyStopping(patience=STOP_PATIENCE, restore_best_weights=True)
#     reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=LR_PATIENCE, verbose=1)

#     callbacks = [early_stopping, reduce_lr]

#     tf.keras.backend.clear_session()
#     history = T2A.fit(x=X_train, validation_split=0.2, epochs=NUM_EPOCHS, batch_size=BATCH_SIZE, callbacks=callbacks, shuffle=True)
#     T2A.save_weights(filepath='/eos/user/h/hjia/ToyVAE/software_dev/software_model/checkpoint_small/Repeat_Testing/small_{}/'.format(i), save_format='tf')

# %%
# signals_file = ["/eos/user/h/hjia/AnomalyDetection/liam_AD/training_notebooks/Ato4l_dataset.h5",
#                 "/eos/user/h/hjia/AnomalyDetection/liam_AD/training_notebooks/hToTauTau_dataset.h5",
#                 "/eos/user/h/hjia/AnomalyDetection/liam_AD/training_notebooks/hChToTauNu_dataset.h5",
#                 "/eos/user/h/hjia/AnomalyDetection/liam_AD/training_notebooks/leptoquark_dataset.h5"]
signal_labels = ["Ato4l",
                "hToTauTau",
                "hChToTauNu",
                "leptoquark"]

# %%
signal_data = [Ato4l_data,
               hToTauTau_data,
               hChToTauNu_data,
               leptoquark_data]
# for i, label in enumerate(signal_labels):
#     with h5py.File(signals_file[i], 'r') as file:
#         test_data = np.array(scaler.transform(file['Data']))
# #         test_data = scale_columns(np.array(file['Data']))
#         signal_data.append(test_data)

# %%
def AD_score_KL(z_mean, z_log_var):
    kl_loss = np.mean(-0.5 * (1 + z_log_var - (z_mean) ** 2 - np.exp(z_log_var)))
    return kl_loss

def AD_score_CKL(z_mean, z_log_var):
    CKL = np.mean(z_mean**2)
    return CKL

class Model_Evaluator:
    def __init__(
        self,
        model_path,
        background,
        br_weights,
        signal,
        signal_weights,
        input_dim,
        title="placeholder",
        save=False,
        labels=None,
    ):

        self.input_dim = input_dim
        vae_enc = Qmake_encoder_set_weights(input_dim, 512,256,48)
        vae_dec = Qmake_decoder_set_weights(input_dim, 512,256,48)
        self.model = VAE_Model(vae_enc, vae_dec)
        self.model.load_weights(model_path)
        self.encoder = self.model.get_layer("encoder")
        self.signal = signal
        self.background = background
        self.br_loss = []
        self.signal_loss = []
        self.background_outputs = []
        self.signal_outputs = []
        self.title = title
        self.saveplots = save
        self.labels = labels
        self.latent_info = []
        self.br_weights = br_weights
        self.signal_weights = signal_weights

    def calculate_loss(self, l_type):
        self.signal_loss = []
        self.br_loss = []
        br = self.background

        if l_type == "CKL":
            br_latent = np.array(self.encoder.predict(br))
            self.latent_info += [br_latent[0]]
            l = []
            for i in range(0, br.shape[0]):
                loss = AD_score_CKL(br_latent[0][i], br_latent[1][i])
                l += [loss]
            self.br_loss = l

            for i, batch in enumerate(self.signal):
                sg_latent = np.array(self.encoder.predict(batch))
                self.latent_info += [sg_latent[0]]
                l = []

                for i in range(0, batch.shape[0]):
                    loss = AD_score_CKL(sg_latent[0][i], sg_latent[1][i])
                    l += [loss]

                sg_loss = l

                self.signal_loss += [sg_loss]

        if l_type == "KL":
            br_latent = np.array(self.encoder.predict(br))
            l = []
            for i in range(0, br.shape[0]):
                loss = AD_score_KL(br_latent[0][i], br_latent[1][i])
                l += [loss]
            self.br_loss = l

            for i, batch in enumerate(self.signal):
                sg_latent = np.array(self.encoder.predict(batch))

                l = []

                for i in range(0, batch.shape[0]):
                    loss = AD_score_KL(sg_latent[0][i], sg_latent[1][i])
                    l += [loss]

                sg_loss = l

                self.signal_loss += [sg_loss]        

    def ROC(self):
        target_fpr = 1e-5
        tpr_at_target = []
        thresholds_at_target = []

        plt.plot(
            np.linspace(0, 1, 1000), np.linspace(0, 1, 1000), "--", label="diagonal"
        )
        for j, batch in enumerate(self.signal_loss):
            sig_w = self.signal_weights[j]
            br_w = self.br_weights
            weights = np.concatenate((br_w, sig_w))
            truth = []
            for i in range(len(self.br_loss)):
                truth += [0]
            for i in range(len(batch)):
                truth += [1]
            ROC_data = np.concatenate((self.br_loss, batch))
            fpr, tpr, thresholds = sk.roc_curve(truth, ROC_data, sample_weight=weights)
            # auc=np.trapz(tpr,fpr)
            auc = sk.roc_auc_score(truth, ROC_data)
            plt.plot(fpr, tpr, label=self.labels[j] + ": " + str(round(auc, 3)))
            
            idx = np.argmin(np.abs(fpr - target_fpr))
            tpr_at_target.append(tpr[idx])
            thresholds_at_target.append(thresholds[idx])


        plt.xlabel("fpr")
        plt.xlim(1e-7, 1)
        plt.ylim(1e-7, 1)
        plt.semilogx()
        plt.ylabel("tpr")
        plt.semilogy()
        plt.title("{}_ROC".format(self.title))
        plt.vlines(10**-5, 0, 1, colors="r", linestyles="dashed")
        plt.legend(loc="lower right")
        if self.saveplots == True:
            plt.savefig(
                "/eos/user/h/hjia/ToyVAE/software_dev/plots/small/{}_ROC.png".format(
                    self.title
                ),
                format="png",
                bbox_inches="tight",
            )
        plt.show()
        
        print(f"\nTPR at FPR = {target_fpr} for each channel:")
        for label, tpr, threshold in zip(self.labels, tpr_at_target, thresholds_at_target):
            print(f"{label}: {tpr*100:.6f}%, Theshold = {threshold:.6f}")

    def GetPerformance(self):
        target_fpr = 1e-5
        tpr_at_target = []

        print(f"Number of signal losses: {len(self.signal_loss)}")
        print(f"Number of labels: {len(self.labels)}")
        print(f"Number of signal weights: {len(self.signal_weights)}")
        print(f"Length of br_loss: {len(self.br_loss)}")

        plt.figure(figsize=(10, 6))
        plt.plot(np.linspace(0, 1, 1000), np.linspace(0, 1, 1000), "--", label="diagonal")

        for j, batch in enumerate(self.signal_loss):
            print(f"Processing batch {j}")
            print(f"Batch length: {len(batch)}")
            print(f"Signal weight length: {len(self.signal_weights[j])}")

            sig_w = self.signal_weights[j]
            br_w = self.br_weights
            weights = np.concatenate((br_w, sig_w))
            truth = np.concatenate([np.zeros(len(self.br_loss)), np.ones(len(batch))])
            ROC_data = np.concatenate((self.br_loss, batch))

            print(f"ROC_data shape: {ROC_data.shape}")
            print(f"truth shape: {truth.shape}")
            print(f"weights shape: {weights.shape}")

            try:
                fpr, tpr, _ = sk.roc_curve(truth, ROC_data, sample_weight=weights)
                auc = sk.roc_auc_score(truth, ROC_data)

                plt.plot(fpr, tpr, label=f"{self.labels[j]}: {auc:.3f}")

                idx = np.argmin(np.abs(fpr - target_fpr))
                tpr_at_target.append(tpr[idx])

                print(f"Successfully processed batch {j}")
            except Exception as e:
                print(f"Error processing batch {j}: {str(e)}")

        plt.xlabel("False Positive Rate")
        plt.ylabel("True Positive Rate")
        plt.xscale('log')
        plt.yscale('log')
        plt.title(f"{self.title} ROC")
        plt.vlines(target_fpr, 0, 1, colors="r", linestyles="dashed")
        plt.legend(loc="lower right")
        if self.saveplots:
            plt.savefig(
                f"/eos/user/h/hjia/ToyVAE/software_dev/plots/small/{self.title}_ROC.png",
                format="png",
                bbox_inches="tight",
            )
        plt.show()

        print(f"\nTPR at FPR = {target_fpr} for each channel:")
        results = list(zip(self.labels, tpr_at_target))
        for label, tpr in results:
            print(f"{label}: {tpr*100:.6f}%")

        print(f"Number of results: {len(results)}")
        return results

# %%
Losses=['CKL']
for string in Losses:
    evaluation=Model_Evaluator('/eos/user/h/hjia/ToyVAE/software_dev/software_model/checkpoint_512_256_48/',
                               X_test,
                               np.ones(len(X_test)),
                               signal_data,
                               [np.ones(len(Ato4l_data)),
                                    np.ones(len(hToTauTau_data)),
                                    np.ones(len(hChToTauNu_data)),
                                    np.ones(len(leptoquark_data))],
                               input_dim = X_test.shape[1],
                               title='VAE Model',
                               save = False,
                               labels = signal_labels)
    evaluation.calculate_loss(string)
    evaluation.ROC()
# Out:
# 25000/25000 [==============================] - 43s 2ms/step
# 1750/1750 [==============================] - 4s 2ms/step
# 21603/21603 [==============================] - 38s 2ms/step
# 23759/23759 [==============================] - 42s 2ms/step
# 10642/10642 [==============================] - 19s 2ms/step
# TPR at FPR = 1e-05 for each channel:
# Ato4l: 8.218835%, Theshold = 5640.644531
# hToTauTau: 0.142489%, Theshold = 5640.644531
# hChToTauNu: 0.123508%, Theshold = 5640.644531
# leptoquark: 0.140657%, Theshold = 5640.644531

# %%
# results = []
# signal_names = ["Ato4l",
#                 "hToTauTau",
#                 "hChToTauNu",
#                 "leptoquark"]
# channel_results = {}
# for i in range(20):
#     try:
#         model_path = f'//eos/user/h/hjia/ToyVAE/software_dev/software_model/checkpoint_small/Repeat_Testing/small_{i}/'
#         print(f"Evaluating model from path: {model_path}")
#         evaluation = Model_Evaluator(model_path,
#                                X_test,
#                                np.ones(len(X_test)),
#                                signal_data,
#                                [np.ones(len(Ato4l_data)),
#                                     np.ones(len(hToTauTau_data)),
#                                     np.ones(len(hChToTauNu_data)),
#                                     np.ones(len(leptoquark_data))],
#                                input_dim = X_test.shape[1],
#                                title='VAE Model {i}',
#                                save = False,
#                                labels = signal_labels)
        
#         print("Model_Evaluator instance created successfully")
        
#         print("Calculating losses...")
#         evaluation.calculate_loss('KL')
#         print("Losses calculated")
        
#         print("Getting performance...")
#         result = evaluation.GetPerformance()
#         print(f"GetPerformance() returned: {result}")
        
#         if not result:
#             print(f"Warning: GetPerformance() returned an empty result for model {i}")
#         else:
#             for channel, tpr in result:
#                 if channel not in channel_results:
#                     channel_results[channel] = []
#                 channel_results[channel].append(tpr)
    
#     except Exception as e:
#         print(f"An error occurred while evaluating model {i}:")
#         print(traceback.format_exc())

# print("Final channel results:", channel_results)

# %%
# if channel_results:
#     plt.figure(figsize=(12, 6))
#     channels = list(channel_results.keys())
#     n_channels = len(channels)
#     n_models = len(channel_results[channels[0]])
    
#     x = np.arange(n_models)
#     width = 0.8 / n_channels
    
#     for i, channel in enumerate(channels):
#         tprs = channel_results[channel]
#         plt.bar(x + i * width, tprs, width, label=channel)
    
#     plt.xlabel('Models')
#     plt.ylabel('True Positive Rate (TPR) at FPR = 1e-5')
#     plt.title('TPR Comparison Across Models and Channels')
#     plt.xticks(x + width * (n_channels - 1) / 2, [f'Model {i}' for i in range(n_models)])
#     plt.legend()
#     plt.tight_layout()
#     plt.savefig('VAE_tpr_comparison_plot.png', dpi=600, bbox_inches='tight')
#     plt.show()
    
#     # Print statistics
#     print("\nChannel Statistics:")
#     for channel in channels:
#         tprs = channel_results[channel]
#         mean = np.mean(tprs)
#         std = np.std(tprs)
#         print(f"{channel}: Mean TPR = {mean*100:.4f}%, Std Dev = {std:.4f}")
# else:
#     print("No results were obtained. Cannot create comparison plot.")

# %%
# if channel_results:
#     plt.figure(figsize=(14, 8))  # Increased figure size to accommodate the legend
#     channels = list(channel_results.keys())
#     n_channels = len(channels)
#     n_models = len(channel_results[channels[0]])
    
#     for i, channel in enumerate(channels):
#         tprs = channel_results[channel]
#         plt.scatter(range(n_models), tprs, label=channel, s=50)
    
#     plt.xlabel('Models')
#     plt.ylabel('True Positive Rate (TPR) at FPR = 1e-5')
#     plt.semilogy()
#     plt.title('TPR Comparison Across Models and Channels')
#     plt.xticks(range(n_models), [f'{i}' for i in range(n_models)])
#     plt.grid(True, linestyle='--', alpha=0.7)
    
#     # Place legend outside the plot
#     plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    
#     plt.tight_layout()
#     plt.savefig('VAE_tpr_comparison_plot.png', dpi=600, bbox_inches='tight')
#     plt.show()
    
#     # Print statistics
#     print("\nChannel Statistics:")
#     for channel in channels:
#         tprs = channel_results[channel]
#         mean = np.mean(tprs)
#         std = np.std(tprs)
#         print(f"{channel}: Mean TPR = {mean:.4f}, Std Dev = {std:.4f}")
# else:
#     print("No results were obtained. Cannot create comparison plot.")

# %%
ori_vae_enc = Qmake_encoder_set_weights(57,512,256,48)
ori_vae_dec = Qmake_decoder_set_weights(57,512,256,48)
orginal_model = VAE_Model(ori_vae_enc, ori_vae_dec)
# orginal_model.predict(Ato4l_data)
orginal_model.load_weights("/eos/user/h/hjia/ToyVAE/software_dev/software_model/checkpoint_512_256_48/")


def make_simplified_encoder(input_dim, h_dim_1, h_dim_2, latent_dim):
    inputs = keras.Input(shape=(input_dim,), name='inputs')
#     x = BatchNormalization(name="BN0")(inputs)
    x = Dense(h_dim_1,
             kernel_initializer=keras.initializers.HeNormal(seed=None),
             bias_initializer=keras.initializers.Zeros(),
             name = "dense1")(inputs)
#     x = BatchNormalization(name="BN1")(x)
    x = ReLU(name="relu1")(x)
    x = Dense(h_dim_2,
             kernel_initializer=keras.initializers.HeNormal(seed=None),
             bias_initializer=keras.initializers.Zeros(),
             name = "dense2")(x)    
#     x = BatchNormalization(name="BN2")(x)
    x = ReLU(name="relu2")(x)
    z_mean=Dense(latent_dim, name='z_mean',
                  kernel_initializer=keras.initializers.HeNormal(seed=None),
                  bias_initializer=keras.initializers.Zeros())(x)
    new_encoder = keras.Model(inputs,z_mean,name='encoder')
    return new_encoder

# %%
new_encoder = make_simplified_encoder(57,512,256,48)
# Transfer weights from the original encoder
for layer in new_encoder.layers:
    if layer.name == "inputs":
        continue
    original_layer = ori_vae_enc.get_layer(layer.name)
    if original_layer is not None:
        print("set weight for ", layer)
        print(original_layer.get_weights())
        layer.set_weights(original_layer.get_weights())
# Out:
# set weight for  <keras.src.layers.core.dense.Dense object at 0x7f998c6ba6a0>
# [array([[ 0.05226023, -0.06299033,  0.08005685, ...,  0.01297885,
#         -0.2439078 ,  0.01471155],
#        [-0.05559416, -0.16131313, -0.01381694, ..., -0.01616945,
#         -0.13914658,  0.2770911 ],
#        [-0.1977182 ,  0.15335475, -0.04085015, ..., -0.06282552,
#         -0.07588202, -0.37674573],
#        ...,
#        [-0.01676303,  0.11224166, -0.12295369, ..., -0.01650283,
#         -0.11264901,  0.08320743],
#        [ 0.00484997,  0.05209833,  0.40083483, ..., -0.00278816,
#          0.23037003, -0.2002849 ],
#        [-0.02693203,  0.09525872, -0.13763711, ..., -0.19107664,
#         -0.255007  , -0.06442698]], dtype=float32), array([ 1.78793117e-01, -4.42729890e-02, -1.27985999e-01, -4.37406786e-02,
#        -4.28629592e-02, -1.05032250e-01,  1.24398746e-01,  1.05220471e-02,
#         1.41909629e-01,  1.47890151e-01,  1.06092244e-01,  5.32481074e-02,
#        -1.19785883e-01, -2.36314476e-01,  2.47196779e-02, -1.02952775e-02,
#         1.12044960e-01,  9.62556973e-02, -8.14917833e-02, -1.20597824e-01,
#        -1.28536895e-01, -7.79274991e-03,  2.83220336e-02,  1.28791124e-01,
#        -5.37037961e-02,  1.34672731e-01,  6.46533743e-02,  2.33411908e-01,
#         1.63491234e-01, -7.99859464e-02,  9.13699940e-02,  1.38981700e-01,
#         8.56016204e-02,  1.12837382e-01,  6.42051846e-02,  8.10083821e-02,
#        -6.30003959e-02, -1.53910033e-02,  3.93286869e-02,  1.15310736e-01,
#        -9.92187709e-02, -1.11185461e-02,  1.18036985e-01, -7.26913065e-02,
#         8.92658085e-02,  1.24608977e-02,  3.52900028e-02,  3.01349937e-04,
#         1.01842331e-02,  3.04299244e-03,  1.34689465e-01, -3.37838428e-04,
#         5.85285425e-02, -1.75958320e-01,  1.49029106e-01,  1.18144199e-01,
#         8.88348743e-02, -1.85245108e-02, -5.42746298e-02,  3.39612328e-02,
#         1.07960574e-01, -7.01842178e-03,  4.06349041e-02,  4.58045565e-02,
#        -4.80706654e-02,  2.17317063e-02, -2.25049225e-05, -1.11011905e-03,
#        -1.01968898e-02, -1.50607212e-03,  7.43823498e-02,  2.77950596e-02,
#         2.16916770e-01,  3.00721109e-01,  1.76382456e-02, -2.71513313e-02,
#         7.43746981e-02,  1.12264000e-01,  7.68278167e-02,  6.28352463e-02,
#         1.06126107e-01,  2.93829609e-02,  9.60704237e-02,  1.23037308e-01,
#         3.63919511e-02, -9.56043303e-02,  1.57072008e-01, -4.12462763e-02,
#         4.04516840e-03,  1.64931640e-01,  2.74516456e-02,  1.26019269e-01,
#        -1.13389380e-01, -1.23472676e-01,  1.68027043e-01, -9.34391618e-02,
#        -3.50867622e-02, -8.84647146e-02, -1.48626804e-01,  2.90329438e-02,
#        -3.48973460e-02,  1.08935777e-02, -1.46901235e-01,  1.82883404e-02,
#         4.84392755e-02,  2.50850199e-03,  9.10217911e-02,  7.02462271e-02,
#         2.68997718e-02,  6.61921054e-02, -2.81961784e-02,  2.42111441e-02,
#         5.90794981e-02, -6.98771700e-02, -2.26490106e-03,  6.13094307e-02,
#         3.25861454e-01, -2.13963538e-02, -6.03722595e-02,  3.88115980e-02,
#         1.96102768e-01, -6.73332512e-02,  1.30260885e-02,  3.90439294e-02,
#        -4.24659289e-02, -5.41948155e-02, -3.15455534e-02, -8.78696293e-02,
#        -3.41010317e-02, -8.71413723e-02,  2.11247340e-01,  5.21075092e-02,
#         7.71055324e-03, -5.34571074e-02, -1.30737096e-01, -7.82035664e-02,
#         2.74501387e-02,  8.39129314e-02, -2.36842632e-02,  2.35564470e-01,
#        -8.68712366e-03,  1.89762458e-01, -9.81884375e-02, -1.77318349e-01,
#         1.23421185e-01,  3.54964435e-02,  3.38955410e-02,  1.52349472e-01,
#        -3.55940722e-02, -1.36831971e-02,  1.03869386e-01,  2.18703654e-02,
#        -9.29690003e-02, -1.67261451e-01,  3.47755253e-02,  4.25150692e-02,
#        -1.33038294e-02,  8.55453610e-02,  5.28268144e-02,  9.39381868e-02,
#         4.31472175e-02,  5.13650067e-02, -5.56550957e-02,  2.04782397e-01,
#         1.61723122e-02,  3.14676315e-02, -1.30576557e-02,  3.86042856e-02,
#         9.43818912e-02,  1.06123998e-03,  2.77371034e-02,  2.65874594e-01,
#        -4.63654083e-04, -7.55044520e-02,  7.46548250e-02, -3.71335112e-02,
#        -1.57921389e-02,  3.18954103e-02, -1.73893981e-02,  4.02421989e-02,
#         1.00284182e-02,  2.83921175e-02, -2.48585474e-02, -1.11040108e-01,
#         2.09178507e-01,  1.04410313e-01,  9.35073346e-02,  7.85504878e-02,
#         1.82916582e-01,  1.27245933e-01, -1.03142010e-02,  1.23027004e-01,
#         7.39766508e-02,  3.66144516e-02,  7.40443096e-02,  1.42967910e-01,
#         1.57040939e-01, -7.15552717e-02,  6.56143576e-02, -2.60916026e-03,
#        -7.48046162e-03, -2.39973553e-02,  9.96350124e-02, -3.14907469e-02,
#        -2.93429587e-02, -1.24319643e-01,  1.21882923e-01,  6.99828491e-02,
#        -6.29619583e-02,  1.04275197e-02, -7.37187490e-02, -2.83858925e-02,
#        -1.93184018e-02,  9.31112692e-02,  3.97029426e-03,  5.00301197e-02,
#         1.44343674e-02,  1.00811660e-01, -9.27499384e-02, -1.18559659e-01,
#         7.67704770e-02, -1.20265387e-01, -4.55587693e-02, -4.85424846e-02,
#        -1.92378044e-01, -1.71851963e-02,  3.10482141e-02,  1.61593169e-01,
#        -1.17659755e-02, -7.21061453e-02,  9.27209184e-02,  2.77841520e-02,
#         2.06274055e-02, -3.17428238e-03, -1.33738248e-02, -2.89498679e-02,
#         8.06370750e-02,  2.55566207e-03,  5.66308759e-02, -9.03060567e-03,
#        -5.62338643e-02,  1.73896670e-01, -5.20184152e-02, -8.33282247e-02,
#         1.44330105e-02, -3.91078778e-02,  2.25412827e-02,  1.87114418e-01,
#         1.67311181e-03,  1.49606675e-01,  1.16230428e-01, -3.16931158e-02,
#         2.47104783e-02, -5.23608439e-02,  5.42013459e-02, -6.08869754e-02,
#        -1.89486623e-01,  1.47707416e-02,  7.96885192e-02, -1.11264534e-01,
#        -7.42183626e-02,  3.66893113e-02,  2.00102672e-01,  1.21845417e-02,
#         1.42939538e-01,  8.11312050e-02,  1.21594265e-01,  1.59586780e-03,
#        -5.79628302e-03,  4.21945453e-02, -1.79290585e-02,  6.99652592e-03,
#        -5.91968261e-02,  1.27502427e-01,  5.59997261e-02,  5.95678482e-03,
#         1.35892063e-01,  9.53398421e-02,  1.31473586e-01,  9.71117169e-02,
#        -5.39185628e-02,  7.24630989e-03, -1.08853029e-02, -7.53514022e-02,
#         1.59018457e-01,  7.04604909e-02,  3.48675884e-02,  4.43354361e-02,
#         8.13389197e-02,  2.04479732e-02, -9.92576964e-03,  7.50173330e-02,
#         7.46265054e-02,  4.96986620e-02, -2.46319696e-02, -8.02248716e-02,
#         7.63529912e-02, -5.77231385e-02, -8.86551738e-02, -6.47850484e-02,
#        -7.65670910e-02, -6.17152750e-02,  1.47080213e-01, -5.64397909e-02,
#        -6.66219592e-02, -1.17219966e-02,  5.54113202e-02,  1.10747054e-01,
#        -3.13219354e-02, -9.46591496e-02, -1.24254534e-02, -2.78708339e-02,
#         6.43552393e-02,  8.48372579e-02, -8.79859403e-02,  2.37576440e-02,
#         2.39195570e-01,  1.05561391e-02, -4.81515117e-02, -2.40707174e-02,
#         1.31014749e-01, -9.40804705e-02,  3.39743614e-01, -4.25823294e-02,
#        -5.55876158e-02,  2.00543497e-02,  1.57842949e-01,  6.26902655e-02,
#         3.12752239e-02,  1.38150267e-02, -7.59912059e-02,  7.29311854e-02,
#         1.28377616e-01, -9.26887915e-02, -4.04345542e-02,  1.33881360e-01,
#        -3.29445489e-02, -4.65831198e-02, -1.50628254e-01,  1.98021587e-02,
#        -1.11016117e-01, -6.00499175e-02, -5.93370525e-03,  1.28455348e-02,
#        -2.10942402e-02, -6.00838400e-02,  4.24683057e-02,  3.64557318e-02,
#        -3.46379504e-02, -6.82810619e-02, -7.44234072e-03,  9.34556648e-02,
#         6.75574020e-02,  1.51743412e-01,  8.01131576e-02, -1.09443367e-01,
#        -2.58329231e-02,  9.48362867e-04, -6.04641624e-02,  5.29112071e-02,
#         3.26507650e-02,  5.15275858e-02,  1.14887379e-01,  9.73775797e-03,
#        -1.02985017e-02,  2.48387698e-02,  4.69372198e-02, -9.72961728e-03,
#         3.54647599e-02,  6.34655869e-03,  4.89332862e-02,  2.02029664e-02,
#         1.96611211e-02,  5.83534874e-02, -8.83491803e-03, -1.23377303e-02,
#        -1.19546384e-01, -5.25465759e-04,  4.88653816e-02, -1.61131322e-02,
#         4.64635193e-02,  1.12287633e-01, -4.75671627e-02, -4.97272983e-02,
#         2.09324149e-04,  5.90658234e-03, -1.97951093e-01,  5.13294935e-02,
#         2.73959320e-02,  7.50923390e-03,  1.77605256e-01,  1.19547047e-01,
#        -9.36686527e-03,  6.56633228e-02,  3.43825258e-02,  1.65153503e-01,
#         5.65935820e-02, -1.45018171e-03, -1.18901953e-01, -2.31842254e-03,
#         2.11064052e-02,  4.01342362e-02, -2.91926637e-02,  6.86490834e-02,
#         1.52079831e-03,  3.56894806e-02, -4.38237973e-02,  2.54586153e-02,
#        -9.50928107e-02,  4.70077991e-02, -5.32759801e-02, -8.04522410e-02,
#        -5.56340814e-02,  3.07212472e-02,  7.87647665e-02,  1.14753194e-01,
#        -4.76720743e-02, -5.85082471e-02,  2.24719360e-01,  8.93097892e-02,
#        -3.14385779e-02,  2.35331175e-03, -9.60807577e-02,  8.90852287e-02,
#        -4.03283946e-02, -1.01044074e-01,  3.21114026e-02, -3.89552042e-02,
#         2.81119589e-02,  5.07646427e-03, -9.49923024e-02,  1.66471340e-02,
#         9.08498913e-02,  6.64114812e-03,  1.83311790e-01,  2.79820487e-02,
#        -8.73896480e-02,  4.09279531e-03,  3.70051488e-02,  2.21929606e-02,
#         3.59514989e-02,  4.37752493e-02, -2.39581931e-02,  5.86103722e-02,
#        -1.53720984e-02,  8.72762874e-02,  7.50323385e-02,  6.98566576e-03,
#         3.94305075e-03,  1.85188409e-02,  1.58616006e-01,  6.09853165e-03,
#         3.29173133e-02, -4.12711091e-02,  5.95601536e-02,  8.04557726e-02,
#        -7.03346953e-02,  2.19153780e-02, -5.58385998e-02,  2.26350967e-03,
#        -5.92543520e-02, -1.17256194e-02, -2.57899053e-02, -1.69677183e-01,
#        -7.72216683e-03,  3.65823545e-02,  1.15659155e-01, -2.25835131e-03,
#         1.96030185e-01, -1.97679624e-02,  1.18450083e-01,  5.59393056e-02,
#        -2.45253593e-02,  1.82530284e-01, -5.52689321e-02, -5.59973940e-02,
#         2.07456201e-02,  2.45074388e-02, -1.02242097e-01, -1.08897693e-01,
#         3.02997585e-02, -3.36803533e-02, -5.58506735e-02,  8.43722671e-02,
#         4.59002815e-02,  2.35346984e-03,  1.79093719e-01,  1.53596565e-01,
#        -3.65877822e-02,  6.06362000e-02,  1.60645440e-01, -9.93187353e-03,
#         6.79098144e-02, -1.25446290e-01, -8.14674199e-02,  1.95233569e-01,
#         4.24432680e-02, -4.89954986e-02,  1.00921653e-02, -9.40676872e-03,
#        -9.53334495e-02, -1.56581029e-01,  1.86373256e-02,  1.19343095e-01,
#         6.65519834e-02,  1.74687244e-02,  9.73699391e-02, -1.45390881e-02,
#        -4.36992850e-03,  4.80769128e-02, -4.18692194e-02, -3.50237451e-02],
#       dtype=float32)]
# set weight for  <keras.src.layers.activation.relu.ReLU object at 0x7f998c5ffc40>
# []
# set weight for  <keras.src.layers.core.dense.Dense object at 0x7f998c57b5b0>
# [array([[ 0.00166333,  0.01582363,  0.00898209, ...,  0.02649371,
#         -0.05470723,  0.02054246],
#        [ 0.00588837,  0.04298894,  0.12455779, ..., -0.08039968,
#         -0.0248708 , -0.02941274],
#        [ 0.09733073, -0.14413042,  0.04550906, ..., -0.01351864,
#          0.04730992,  0.02023096],
#        ...,
#        [-0.02584163,  0.11358672, -0.01534102, ..., -0.11180274,
#         -0.01427867,  0.01302678],
#        [ 0.03047586, -0.06784289,  0.00590543, ...,  0.00447341,
#         -0.08259149, -0.03349565],
#        [ 0.03943421,  0.05751216, -0.04679406, ...,  0.08834097,
#         -0.08918351,  0.04603384]], dtype=float32), array([-2.22197492e-02, -3.23687568e-02, -1.14139989e-02,  5.07933795e-02,
#         1.60375968e-01,  6.73672110e-02,  2.34531283e-01,  8.29949155e-02,
#         8.11959524e-03,  2.98025627e-02,  5.41022867e-02,  2.05186140e-02,
#        -1.31478216e-02,  5.18764481e-02,  9.83618386e-03,  1.48788080e-01,
#         2.86133010e-02, -1.38845304e-02,  8.95442441e-02, -1.15411608e-02,
#         7.97687024e-02, -1.30599877e-02,  1.19855411e-01,  5.81834838e-02,
#        -1.10149533e-01,  1.06616549e-01,  9.02643800e-02, -1.86505690e-02,
#        -9.03455690e-02, -1.15476949e-02,  2.24046931e-02,  4.36644047e-01,
#        -1.32808024e-02, -6.29854097e-04, -9.18470509e-03,  9.55331847e-02,
#        -8.99141002e-03, -1.45186484e-02,  7.85964653e-02, -5.73845254e-03,
#         1.85585953e-02, -1.57518368e-02,  1.44519806e-01,  1.92107148e-02,
#        -1.12613067e-02,  5.39770089e-02, -3.25998999e-02, -3.05117015e-02,
#        -2.13997532e-02,  7.61243030e-02, -1.12543879e-02, -1.40048144e-02,
#         5.74460626e-02,  5.37299104e-02,  1.41758695e-01, -2.02801786e-02,
#        -2.24246993e-03, -2.38693282e-02, -1.81389675e-02,  4.35541384e-02,
#         1.74224049e-01,  1.41953751e-01,  4.60488871e-02,  7.94213414e-02,
#         3.05856485e-02, -1.10497503e-02,  1.10170364e-01, -1.11130308e-02,
#        -9.99925379e-03,  1.27466336e-01, -2.62805559e-02,  3.93005423e-02,
#         5.15252426e-02, -1.08798807e-02, -3.61407585e-02, -1.13400491e-02,
#         1.03694834e-01,  4.71785739e-02,  7.31433555e-02, -1.17388330e-02,
#         2.25851834e-01,  1.03802115e-01, -1.14923995e-02, -1.58961322e-02,
#         6.61477167e-03, -4.35139239e-03,  7.33142346e-02,  8.27196687e-02,
#        -1.23652769e-02, -1.28813870e-02, -2.44649649e-02, -6.93454826e-03,
#        -9.18610953e-03, -1.08361207e-02,  1.55259416e-01, -3.11589381e-03,
#         6.73558712e-02,  3.34064523e-03,  1.51037136e-02,  3.24091583e-04,
#        -1.17890397e-02,  1.61779046e-01,  3.83151025e-02,  1.82951614e-01,
#        -1.28689250e-02,  4.54517193e-02, -1.77209340e-02,  3.16943079e-02,
#        -1.15433550e-02, -1.67082306e-02,  5.65664880e-02,  5.15524074e-02,
#         1.07131405e-02,  8.30370262e-02,  8.70847050e-03, -1.00897513e-02,
#         5.71074970e-02, -1.43348146e-02,  1.62802134e-02,  2.90759318e-02,
#         8.40895474e-02, -9.97528248e-03,  6.16331883e-02, -1.70048345e-02,
#         1.65216982e-01,  1.78330511e-01,  2.15117447e-02, -2.18754299e-02,
#        -1.29807480e-02,  4.96019349e-02,  3.12671587e-02, -7.00457301e-03,
#        -1.66495275e-02, -1.47126988e-02,  9.52369720e-02, -8.72019958e-03,
#        -1.95164625e-02, -2.07552537e-02, -6.78583793e-03,  2.92197876e-02,
#         2.17939734e-01,  7.77608075e-05,  1.69604167e-01, -5.69167100e-02,
#         2.25529987e-02, -1.64460503e-02,  8.05541798e-02,  7.58406222e-02,
#        -5.29938973e-02,  6.43644156e-03,  2.04887912e-02, -2.44380794e-02,
#        -5.52890403e-03,  6.72454089e-02, -1.50270294e-02, -9.20764543e-03,
#         8.64837915e-02, -6.94941217e-03,  1.50278300e-01, -4.45792377e-02,
#        -2.53948905e-02, -3.39777097e-02, -2.21525524e-02, -4.66298573e-02,
#        -3.65929417e-02, -1.28726764e-02, -2.37504262e-02,  1.31563216e-01,
#         1.99850602e-03,  1.42742589e-01, -8.18528514e-03,  2.40985438e-01,
#        -1.15973065e-02,  1.70402065e-01, -1.07086617e-02,  5.84015027e-02,
#         9.01156198e-03, -1.08068585e-02, -7.04972958e-03, -7.14742392e-02,
#        -5.25945425e-03,  1.04042478e-01, -1.07298996e-02,  1.19900092e-01,
#         1.22592472e-01,  1.00283861e-01, -3.88198420e-02,  6.96662664e-02,
#        -9.53563210e-03,  1.07068896e-01, -7.52238370e-03, -6.82488307e-02,
#         3.59879471e-02,  8.98401439e-03, -1.37717370e-02, -2.56155971e-02,
#        -1.12063838e-02, -6.54216530e-03,  4.95091528e-02,  1.90016270e-01,
#        -3.31677054e-03, -1.37733109e-02,  6.45716339e-02, -2.09629163e-02,
#        -3.28582644e-01, -1.31863365e-02, -1.09378612e-02, -4.76280972e-03,
#        -1.68411881e-02, -1.68387778e-02,  9.21811089e-02, -5.53083345e-02,
#        -9.24815517e-03,  2.40227859e-02, -1.82646513e-02, -2.45635793e-01,
#        -1.04143685e-02, -2.46538371e-02, -1.43458573e-02, -9.67861339e-03,
#        -1.75082143e-02,  5.29910577e-03, -2.69057695e-02,  9.86421853e-03,
#         4.54108678e-02, -1.37427580e-02, -1.08053377e-02, -8.51978920e-03,
#        -1.07782912e-02, -2.31569596e-02, -1.30616520e-02,  4.37064581e-02,
#        -2.47828793e-02,  1.30653992e-01,  7.68066049e-02, -1.29453272e-01,
#        -2.36248854e-03,  6.19306155e-02, -2.79099634e-03, -3.60933482e-03,
#         5.23797572e-02,  9.24092310e-04, -1.66996084e-02, -8.51462130e-03,
#         1.39827833e-01,  1.39288127e-01,  1.39803849e-02, -9.26888268e-03,
#         1.11518234e-01,  4.62531559e-02,  1.71522364e-01,  7.65113682e-02,
#        -7.64982635e-03,  1.49922888e-03,  6.77170744e-03,  2.03625672e-02],
#       dtype=float32)]
# set weight for  <keras.src.layers.activation.relu.ReLU object at 0x7f998c5f8640>
# []
# set weight for  <keras.src.layers.core.dense.Dense object at 0x7f998c5c45b0>
# [array([[-0.07544361,  0.04957422,  0.00849718, ...,  0.09313314,
#         -0.03895988,  0.00501067],
#        [ 0.06738753,  0.038351  ,  0.01681995, ..., -0.08617549,
#         -0.09970181, -0.00833952],
#        [-0.1434754 , -0.15250923,  0.07908777, ..., -0.12102614,
#          0.12358637,  0.09143601],
#        ...,
#        [-0.07521797, -0.0266491 ,  0.08090036, ...,  0.06998769,
#          0.11549187, -0.08429355],
#        [ 0.07220367,  0.01306752, -0.00945269, ..., -0.11590164,
#         -0.06208106, -0.04155117],
#        [-0.05763346, -0.0826862 ,  0.00237799, ...,  0.04999658,
#         -0.03486383,  0.1097076 ]], dtype=float32), array([ 0.03675801,  0.00979955,  0.02302797, -0.03250261, -0.0526084 ,
#        -0.14061135,  0.02113294,  0.00618997,  0.00541071,  0.01604676,
#         0.01766258, -0.00434553, -0.05711832,  0.0121847 ,  0.00720422,
#        -0.01555883, -0.04036875,  0.04685341, -0.01041084,  0.03972803,
#         0.01544954, -0.04678423, -0.04578229, -0.05720537, -0.00821384,
#        -0.04514822, -0.07301444, -0.10109293,  0.00894764, -0.02919305,
#        -0.03405648,  0.04636713, -0.05797964,  0.01810556, -0.01927615,
#        -0.01373898,  0.00949323, -0.00652515,  0.08319907, -0.02541655,
#         0.04844254, -0.01444935,  0.09540193,  0.01602144, -0.01932178,
#        -0.03172217,  0.05667511,  0.03781003], dtype=float32)]

# %%
tf.keras.models.save_model(new_encoder, 'VAE_40MHZ_model_512_256_48_onchip', save_format='tf')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: VAE_40MHZ_model_512_256_48_onchip/assets
# INFO:tensorflow:Assets written to: VAE_40MHZ_model_512_256_48_onchip/assets
